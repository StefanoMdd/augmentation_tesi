# %%
import ants
image = ants.image_read("OASIS_BRAIN_1/sub-OAS30010_ses-d0068_T1w.nii.gz")
ants.plot(image, crop=False)

# %%
image2 = ants.n4_bias_field_correction(image)

# %%
ants.plot(image2, crop=False)

# %%
filename = "provaN4biascorrected.nii.gz"
ants.image_write(image2, filename, ri=False)
